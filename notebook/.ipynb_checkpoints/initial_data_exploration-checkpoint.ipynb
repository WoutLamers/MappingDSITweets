# %%
import pandas as pd
import networkx as nx

# %%
df = pd.read_json('C:/Users/lamersws1/Documents/Data/firstdata.json')

# %%
df.head()
# Out:
#    contributors          ...          withheld_in_countries
# 0           NaN          ...                           None
# 1           NaN          ...                           None
# 2           NaN          ...                           None
# 3           NaN          ...                           None
# 4           NaN          ...                           None
#
# [5 rows x 38 columns]

# %% [markdown]
# Explore available collumns

# %%
list(df)
# Out:
# ['contributors',
#  'coordinates',
#  'created_at',
#  'display_text_range',
#  'entities',
#  'extended_entities',
#  'extended_tweet',
#  'favorite_count',
#  'favorited',
#  'filter_level',
#  'geo',
#  'id',
#  'id_str',
#  'in_reply_to_screen_name',
#  'in_reply_to_status_id',
#  'in_reply_to_status_id_str',
#  'in_reply_to_user_id',
#  'in_reply_to_user_id_str',
#  'is_quote_status',
#  'lang',
#  'limit',
#  'place',
#  'possibly_sensitive',
#  'quote_count',
#  'quoted_status',
#  'quoted_status_id',
#  'quoted_status_id_str',
#  'quoted_status_permalink',
#  'reply_count',
#  'retweet_count',
#  'retweeted',
#  'retweeted_status',
#  'source',
#  'text',
#  'timestamp_ms',
#  'truncated',
#  'user',
#  'withheld_in_countries']

# %%
df.describe()
# Out:
#        contributors  favorite_count     ...       retweeted    truncated
# count           0.0          9999.0     ...          9999.0  9999.000000
# mean            NaN             0.0     ...             0.0     0.214621
# std             NaN             0.0     ...             0.0     0.410580
# min             NaN             0.0     ...             0.0     0.000000
# 25%             NaN             0.0     ...             0.0     0.000000
# 50%             NaN             0.0     ...             0.0     0.000000
# 75%             NaN             0.0     ...             0.0     0.000000
# max             NaN             0.0     ...             0.0     1.000000
#
# [8 rows x 18 columns]

# %% [markdown]
# Let's look at hashtags

# %%
df[df['entities'].isnull()]
# Out:
#       contributors coordinates          ...           user withheld_in_countries
# 3758           NaN        None          ...           None                  None
#
# [1 rows x 38 columns]

# %% [markdown]
# Remove this useless record from the data

# %%
df = df[df['entities'].isnull() == False]

# %% [markdown]
# Let's look at the mentions network

# %%
def extract_mentions(df):

    out = []

    for index, row in df.iterrows():

        if isinstance(row.user, dict):
        
            assert isinstance(row.user, dict), "user is not dict in {}".format(index)
            assert isinstance(row.entities, dict), "entities is not dict in {}".format(index)
            usermentions = row.entities['user_mentions']

            for u in usermentions:
                out.append((row.user['id'], u['id']))
    
    return out

# %%
mentions = extract_mentions(df)

# %%
def extract_users(df):
    
    users = [(u['id'], u['screen_name'], u['name']) for u in df['user'] if isinstance(u, dict)]
    users = list(set(users))
    
    user_mentions = [u['user_mentions'] for u in df['entities'] if isinstance(u, dict)]
    for l in user_mentions:
        for u in l:
            users.append((u['id'], u['screen_name'], u['name']))
        
    users = list(set(users))
    
    users = {u[0]: {'name': u[2], 'screen_name': u[1]} for u in users}
    
    return users

# %%
users = extract_users(df)

# %%
G=nx.Graph()
G.add_edges_from(mentions)
nx.set_node_attributes(G, users)

# %%
Ggc = sorted(nx.connected_components(G), key=len, reverse=True)

# %%
SG = G.subgraph(Ggc[0])
top_connected_nodes = [x[0] for x in SG.degree() if x[1] > 10]
SG = G.subgraph(top_connected_nodes)

# %%
SG

# %%
nx.draw_networkx(SG)

# %%
SG.nodes
# Out:
# NodeView((950750435882733568, 948587899024564225, 722401302811144194, 822215679726100480, 190277762, 127289989, 790627436832579584, 929050108523679745, 864126967515426816, 3391720966, 818910970567344128, 299659914, 18994444, 2523447146, 6705042, 27955989, 608523926, 212123929, 138966937, 1449670430, 424552610, 14109218, 165933992, 1229453994, 380617006, 1483245362, 2366194867, 377473204, 163154809, 3227338044, 16717501, 2425151, 3023811, 1286116932, 17888709, 64482503, 2205307848, 2980633674, 4502885068, 14780493, 3072905932, 194563663, 384879060, 25073877, 18873177, 1976143068, 115065053, 167193309, 2799996893, 209309794, 212325987, 988310476173045760, 74286565, 21561061, 975548535067348992, 16977387, 20571756, 3310089706, 557996780, 339061487, 867947619661881344, 1367531, 17874544, 538455539, 63786611, 80528373, 533047414, 3228602741, 15976697, 14706299, 9737982, 146423935))

# %%
nx.write_graphml(SG,'so.graphml')
