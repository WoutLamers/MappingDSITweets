# %%
import pandas as pd
import networkx as nx

# %%
df = pd.read_json('C:/Users/lamersws1/Documents/Data/firstdata.json')

# %%
df.head()
# Out:
#       index                        ...                                                                   entities
# 0         0                        ...                          {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 1         1                        ...                          {'hashtags': [{'text': 'Hipismo', 'indices': [...
# 10       10                        ...                          {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 100     100                        ...                          {'hashtags': [{'text': 'VivaTech', 'indices': ...
# 1000   1000                        ...                          {'hashtags': [{'text': 'fundraising', 'indices...
#
# [5 rows x 10 columns]

# %% [markdown]
# Explore available collumns

# %%
list(df)
# Out:
# ['index',
#  'coordinates',
#  'created_at',
#  'user',
#  'timestamp_ms',
#  'text',
#  'retweet_count',
#  'retweeted_status',
#  'reply_count',
#  'entities']

# %%
df.describe()
# Out:
#                index  retweet_count  reply_count
# count  150000.000000       149999.0     149999.0
# mean     4999.500000            0.0          0.0
# std      2886.760954            0.0          0.0
# min         0.000000            0.0          0.0
# 25%      2499.750000            0.0          0.0
# 50%      4999.500000            0.0          0.0
# 75%      7499.250000            0.0          0.0
# max      9999.000000            0.0          0.0

# %% [markdown]
# Let's look at hashtags

# %%
df[df['entities'].isnull()]
# Out:
#       index coordinates   ...    reply_count entities
# 3758   3758        None   ...            NaN     None
#
# [1 rows x 10 columns]

# %% [markdown]
# Remove this useless record from the data

# %%
df = df[df['entities'].isnull() == False]

# %% [markdown]
# Let's look at the mentions network

# %%
def extract_mentions(df):

    out = []

    for index, row in df.iterrows():

        if isinstance(row.user, dict):
        
            assert isinstance(row.user, dict), "user is not dict in {}".format(index)
            assert isinstance(row.entities, dict), "entities is not dict in {}".format(index)
            usermentions = row.entities['user_mentions']

            for u in usermentions:
                out.append((row.user['id'], u['id']))
    
    return out

# %%
mentions = extract_mentions(df)

# %%
def extract_users(df):
    
    users = [(u['id'], u['screen_name'], u['name']) for u in df['user'] if isinstance(u, dict)]
    users = list(set(users))
    
    user_mentions = [u['user_mentions'] for u in df['entities'] if isinstance(u, dict)]
    for l in user_mentions:
        for u in l:
            users.append((u['id'], u['screen_name'], u['name']))
        
    users = list(set(users))
    
    users = {u[0]: {'name': u[2], 'screen_name': u[1]} for u in users}
    
    return users

# %%
users = extract_users(df)

# %%
G=nx.Graph()
G.add_edges_from(mentions)
nx.set_node_attributes(G, users)

# %%
Ggc = sorted(nx.connected_components(G), key=len, reverse=True)

# %%
SG = G.subgraph(Ggc[0])
top_connected_nodes = [x[0] for x in SG.degree() if x[1] > 25]
SG = G.subgraph(top_connected_nodes)
SG = SG.subgraph(sorted(nx.connected_components(SG), key=len, reverse=True)[0])

# %%
len(SG.nodes())
# Out:
# 404

# %%
nx.draw_networkx(SG)

# %%
SG.nodes
# Out:
 19526809, 915609293377998854, 275686563, 7617702, 85535913, 19485870, 13486, 2366194867, 3364396215, 14998722, 64482503, 17925320, 24822993, 1389781, 1976143068, 3018841323, 621169905, 9989362, 1118579966, 867947619661881344, 880570939779555328, 822215679726100480, 887385484489629697, 789090073383796736, 18994444, 25390350, 563977493, 3071844357, 5541152, 396451105, 88892707, 15615271, 3121151275, 11134252, 252024110, 252204344, 3227338044, 925827012488396800, 37721424, 2150950224, 49698134, 115660120, 352650591, 64017773, 1374547314, 14916980, 901397859613978624, 864126967515426816, 988867652805328896, 720622633029644289, 790654887465975808, 981031334201131008, 1095841166, 14800270, 856446453157376003, 254107028, 4716205469, 4374719908, 118115748, 2599005608, 1551015338, 66780587, 84321709, 14425522, 186682805, 17888709, 90435017, 4263007693, 759251, 284724697, 74286565, 16977387, 380749300, 863265441136885760, 534255106, 3391720966, 14335498, 816653, 6649362, 288755234, 19017255, 64192042, 13348402, 9799222, 15531582, 21333 ...

# %%
nx.write_graphml(SG,'so.graphml')

# %%
SG.nodes.data()
# Out:
# NodeDataView({875882643614814208: {'name': 'Mastodon', 'screen_name': 'MastodonProject'}, 915976368571027457: {'name': 'Luke Valenty', 'screen_name': 'TinyFPGA'}, 869794196294520832: {'name': 'Machine Learning', 'screen_name': 'machinelearn_d'}, 877788798687621121: {'name': 'Linux Environment', 'screen_name': 'linux_en'}, 905993768624472065: {'name': 'Java Technology', 'screen_name': 'java_tec'}, 781608889515069440: {'name': 'Robo Jesse', 'screen_name': 'sockeyes51_bot'}, 1002997262727839744: {'name': 'movingtogitlab', 'screen_name': 'movingtogitlab'}, 910170788602429440: {'name': 'Mastering PHP', 'screen_name': 'php_lea'}, 988310476173045760: {'name': 'CC.EXE', 'screen_name': 'CC_CURATOR'}, 973897363491180544: {'name': 'Code For The People', 'screen_name': 'codeforthepeopl'}, 736185001457287169: {'name': 'Helene Li ??', 'screen_name': 'helene_wpli'}, 950095434952921090: {'name': 'Iconic ICOs Ecosystem', 'screen_name': 'joiniconic'}, 992547386047320071: {'name': 'Mario Falso', 'screen_name': 'mario_falso'}, 822491301484576772: {'name': 'Tami Burages', 'screen_name': 'tburages'}, 701625454915026945: {'name': 'PreferredNetworksJP', 'screen_name': 'PreferredNetJP'}, 2737534982: {'name': 'NativeScript', 'screen_name': 'NativeScript'}, 989920160004833283: {'name': 'Bloqboard', 'screen_name': 'bloqboard'}, 125128723: {'name': 'Raheem', 'screen_name': 'RaheemKassam'}, 489377813: {'name': 'Liz Webster????????? #FBPE', 'screen_name': 'abcpoppins'}, 290576429: {'name': 'Municipalidad de Cba', 'screen_name': 'MuniCba'}, 2983206962: {'name': 'U.S. Digital Service', 'screen_name': 'USDS'}, 35749949: {'name': 'David Schwartz', 'screen_name': 'JoelKatz'}, 272896062: {'name': 'Guillaume Chau', 'screen_name': 'Akryum'}, 1565485130: {'name': 'Jose Luis Franco', 'screen_name': 'FrancoTumas'}, 241045580: {'name': 'Maddyness', 'screen_name': 'bymaddyness'}, 393429073: {'name': 'LearnEnjoy', 'screen_name': 'LEARNENJOY'}, 296824934: {'name': 'Orange', 'screen_name': 'orange'}, 45615218: {'name': 'Christiaan Triebert', 'screen_name': 'trbrtc'}, 8736882: {'name': 'The Globe and Mail', 'screen_name': 'globeandmail'}, 26155124: {'name': 'David Meza', 'screen_name': 'davidmeza1'}, 765651407336771584: {'name': 'OGP Toolbox', 'screen_name': 'ogptoolbox'}, 913187906440663040: {'name': 'Deconet', 'screen_name': 'Deco_Network'}, 705539763349164032: {'name': 'ipfconline', 'screen_name': 'ipfconline1'}, 14237828: {'name': 'MarleneSchiappa', 'screen_name': 'MarleneSchiappa'}, 819571243489824769: {'name': 'CDS', 'screen_name': 'CDS_GC'}, 774689518767181828: {'name': 'Status', 'screen_name': 'ethstatus'}, 8917142: {'name': 'Dan Kaminsky', 'screen_name': 'dakami'}, 473958550: {'name': 'Sparknews', 'screen_name': 'Sparknews'}, 3600750743: {'name': 'GobAbiertoLocal', 'screen_name': 'GobAbiertoLocal'}, 119867548: {'name': 'Vanessa Vincent', 'screen_name': 'VanessaVincentR'}, 19230878: {'name': 'SAP News', 'screen_name': 'sapnews'}, 1075460258: {'name': 'chairman mow', 'screen_name': 'Chairmnoomowmow'}, 172621993: {'name': 'Ivan Pavel', 'screen_name': 'maxcorpiz'}, 3819701: {'name': 'ZDNet', 'screen_name': 'ZDNet'}, 807095: {'name': 'The New York Times', 'screen_name': 'nytimes'}, 3905851578: {'name': 'Opencity Inc', 'screen_name': 'OpencityInc'}, 92991679: {'name': 'UNCUYO', 'screen_name': 'UNCuyo'}, 17230018: {'name': 'Spotify', 'screen_name': 'Spotify'}, 2292889800: {'name': 'Vue.js', 'screen_name': 'vuejs'}, 125485258: {'name': 'Java', 'screen_name': 'java'}, 1526345940: {'name': 'Fundación Conocimiento Abierto', 'screen_name': 'OKFNAR'}, 25073877: {'name': 'Donald J. Trump', 'screen_name': 'realDonaldTrump'}, 115065053: {'name': 'FlashTweet ??', 'screen_name': 'FlashTweet'}, 14184671: {'name': 'Mark Headd', 'screen_name': 'mheadd'}, 1318826208: {'name': 'Doug Ayers', 'screen_name': 'DouglasCAyers'}, 13334762: {'name': 'GitHub', 'screen_name': 'github'}, 13623532: {'name': 'Sebastian Piñera', 'screen_name': 'sebastianpinera'}, 35203319: {'name': 'Evan Kirstel', 'sc ...
